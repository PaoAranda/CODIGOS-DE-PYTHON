# %% [markdown]
# tipos de variables a retornar

# %% [markdown]
# strigns

# %% [markdown]
# Booleanos

# %%
def is_pair(n)
if n%2 == 0:
  return True
  return False

  pirnt(is_pair(8))
  pirnt(is_pair(5))

# %% [markdown]
# Listas

# %%
def find_pair(n):
  pairs = []
  for i in range(n+1):
    if i%2 == 0:
      pairs.apped(i)
      return pairs

      print(find_pair(20))
